# %% [markdown]
# # Homework 0
#
# In this homework, you will get familiarized with running Python script on Google Colab with GPU capability. Follow the steps and submit the Google Colab notebook with outputs to receive full credits.

# %% [markdown]
# ## Step 1: Create a Google Colab project from Google Drive
#
# This is the easiest way to create a Google Colab project and store relevant files.

# %% [markdown]
# <img src="https://github.com/yuankaihuo/DL_course_hw/blob/master/Homework%200/pic/1.png?raw=true" width="600"/>

# %% [markdown]
# ## Step 2: Change file name and switch to GPU

# %% [markdown]
# <img src="https://github.com/yuankaihuo/DL_course_hw/blob/master/Homework%200/pic/2.png?raw=true" width="600"/>

# %% [markdown]
# <img src="https://github.com/yuankaihuo/DL_course_hw/blob/master/Homework%200/pic/3.png?raw=true" width="600"/>

# %% [markdown]
# <img src="https://github.com/yuankaihuo/DL_course_hw/blob/master/Homework%200/pic/4.png?raw=true" width="300"/>

# %% [markdown]
# ## Step 3: Link Google Colab with Google Drive for file transfer

# %% [markdown]
# Copy and paste the following code to link Google Drive with Google Colab

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ## Step 4: Change the working directory and download the python script

# %%
# %cd gdrive/My\ Drive/Colab\ Notebooks/hw0
# Out:
# /content/gdrive/My Drive/Colab Notebooks/hw0

# %% [markdown]
# Go to https://github.com/pytorch/examples/blob/master/mnist/main.py , download the script to your working directory

# %% [markdown]
# ## Step 5: Run the script

# %%
# %run main.py
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.333409
# Train Epoch: 1 [640/60000 (1%)]	Loss: 1.268087
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 0.831068
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 0.606637
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 0.352703
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 0.396755
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 0.289980
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 0.225877
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.420060
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 0.230234
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 0.314567
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 0.273931
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 0.334259
# Train Epoch: 1 [8320/60000 (14%)]	Loss: 0.250874
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 0.343389
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 0.079107
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.093477
# Train Epoch: 1 [10880/60000 (18%)]	Loss: 0.201430
# Train Epoch: 1 [11520/60000 (19%)]	Loss: 0.289598
# ...

# %% [markdown]
# ## Grading
#
# Submit your Colab notebook in either `ipynb` or `pdf` (preferred) format. If you are able to reproduce the results, then you will receive a Pass. Otherwise, you will receive a Fail. Your grade from Hoemwork 0 doesn't impact your final grade on homework. More details on
